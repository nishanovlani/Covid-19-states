# %%
import pandas as pd

# %%
data = pd.read_csv('file.csv')

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455
# 2  4/29/2020    MI      Algeria       3848     444       1702
# 3  4/29/2020    CA      Andorra        743      42        423
# 4  4/29/2020    LA       Angola         27       2          7

# %%
 data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020        NY     Afghanistan       1939      60        252
# 1    4/29/2020        NJ         Albania        766      30        455
# 2    4/29/2020        MI         Algeria       3848     444       1702
# 3    4/29/2020        CA         Andorra        743      42        423
# 4    4/29/2020        LA          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        218
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False  False   False      False   False      False
# 1    False  False   False      False   False      False
# 2    False  False   False      False   False      False
# 3    False  False   False      False   False      False
# 4    False  False   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date           0
# State        103
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455

# %%
data.groupby('Region').sum()
# Out:
#                          Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020    NY       1939      60        252
# Albania             4/29/2020    NJ        766      30        455
# Algeria             4/29/2020    MI       3848     444       1702
# Andorra             4/29/2020    CA        743      42        423
# Angola              4/29/2020    LA         27       2          7
# ...                       ...   ...        ...     ...        ...
# West Bank and Gaza  4/29/2020     0        344       2         71
# Western Sahara      4/29/2020     0          6       0          5
# Yemen               4/29/2020     0          6       0          1
# Zambia              4/29/2020     0         97       3         54
# Zimbabwe            4/29/2020     0         32       4          5
#
# [187 rows x 5 columns]

# %%
data.groupby('Region').sum().head(20)
# Out:
#                                                                   Date  \
# Region
# Afghanistan                                                  4/29/2020
# Albania                                                      4/29/2020
# Algeria                                                      4/29/2020
# Andorra                                                      4/29/2020
# Angola                                                       4/29/2020
# Antigua and Barbuda                                          4/29/2020
# Argentina                                                    4/29/2020
# Armenia                                                      4/29/2020
# Australia            4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                      4/29/2020
# Azerbaijan                                                   4/29/2020
# Bahamas                                                      4/29/2020
# ...

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455

# %%
data.groupby('Region')[['Confirmed', 'Recovered']].sum() .head(15)
# Out:
#                      Confirmed  Recovered
# Region
# Afghanistan               1939        252
# Albania                    766        455
# Algeria                   3848       1702
# Andorra                    743        423
# Angola                      27          7
# Antigua and Barbuda         24         11
# Argentina                 4285       1192
# Armenia                   1932        900
# Australia                 6752       5715
# Austria                  15402      12779
# Azerbaijan                1766       1267
# Bahamas                     80         23
# Bahrain                   2921       1455
# Bangladesh                7103        150
# Barbados                    80         39

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455

# %%
data.Confirmed<10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
data[data.Confirmed < 10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                                NC                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data[~(data.Confirmed < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020        NY     Afghanistan       1939      60        252
# 1    4/29/2020        NJ         Albania        766      30        455
# 2    4/29/2020        MI         Algeria       3848     444       1702
# 3    4/29/2020        CA         Andorra        743      42        423
# 4    4/29/2020        LA          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data = data[~(data.Confirmed < 10)]
#TO remove the records satisfied a particular condition

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020    NY             Afghanistan       1939      60        252
# 1   4/29/2020    NJ                 Albania        766      30        455
# 2   4/29/2020    MI                 Algeria       3848     444       1702
# 3   4/29/2020    CA                 Andorra        743      42        423
# 4   4/29/2020    LA                  Angola         27       2          7
# 5   4/29/2020    MA     Antigua and Barbuda         24       3         11
# 6   4/29/2020    FL               Argentina       4285     214       1192
# 7   4/29/2020    IL                 Armenia       1932      30        900
# 8   4/29/2020    PA                 Austria      15402     580      12779
# 9   4/29/2020    WA              Azerbaijan       1766      23       1267
# 10  4/29/2020    GA                 Bahamas         80      11         23
# 11  4/29/2020    TX                 Bahrain       2921       8       1455
# ...

# %%
data.groupby('Region').Confirmed.sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# Venezuela              331
# Vietnam                270
# West Bank and Gaza     344
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 180, dtype: int64

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False)
# Out:
# Region
# US            1039909
# Spain          236899
# Italy          203591
# France         166536
# UK             166432
#                ...
# Seychelles         11
# Burundi            11
# Suriname           10
# Gambia             10
# Holy See           10
# Name: Confirmed, Length: 180, dtype: int64

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455

# %%
data.groupby('Region').Deaths.sum()
# Out:
# Region
# Afghanistan            60
# Albania                30
# Algeria               444
# Andorra                42
# Angola                  2
#                      ...
# Venezuela              10
# Vietnam                 0
# West Bank and Gaza      2
# Zambia                  3
# Zimbabwe                4
# Name: Deaths, Length: 180, dtype: int64

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=False)
# Out:
# Region
# US                          60967
# Italy                       27682
# UK                          26165
# Spain                       24275
# France                      24121
#                             ...
# Mozambique                      0
# Mongolia                        0
# Central African Republic        0
# Cambodia                        0
# Grenada                         0
# Name: Deaths, Length: 180, dtype: int64

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455

# %%
data.Region == 'India'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Region, Length: 304, dtype: bool

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020    FL  India      33062    1079       8437

# %%
data[data.Region == 'Albania']
# Out:
#         Date State   Region  Confirmed  Deaths  Recovered
# 1  4/29/2020    NJ  Albania        766      30        455

# %%
data[data.Region == 'UK']
# Out:
#           Date                        State Region  Confirmed  Deaths  \
# 168  4/29/2020                          NaN     UK     165221   26097
# 191  4/29/2020                      Bermuda     UK        111       6
# 196  4/29/2020               Cayman Islands     UK         73       1
# 197  4/29/2020              Channel Islands     UK        537      38
# 206  4/29/2020  Falkland Islands (Malvinas)     UK         13       0
# 214  4/29/2020                    Gibraltar     UK        141       0
# 236  4/29/2020                  Isle of Man     UK        313      21
# 256  4/29/2020                   Montserrat     UK         11       1
# 306  4/29/2020     Turks and Caicos Islands     UK         12       1
#
#      Recovered
# 168          0
# 191         48
# 196         10
# 197        386
# 206         11
# 214        131
# 236        258
# 256          2
# 306          5

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020    NY  Afghanistan       1939      60        252
# 1  4/29/2020    NJ      Albania        766      30        455

# %%
data.sort_values(by = ['Confirmed'], ascending = True)
# Out:
#           Date      State    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020        NaN  Suriname         10       1          8
# 70   4/29/2020         MI  Holy See         10       0          2
# 59   4/29/2020         CA    Gambia         10       1          8
# 318  4/29/2020      Yukon    Canada         11       0          0
# 217  4/29/2020  Greenland   Denmark         11       0         11
# ..         ...        ...       ...        ...     ...        ...
# 57   4/29/2020         NJ    France     165093   24087      48228
# 168  4/29/2020        NaN        UK     165221   26097          0
# 80   4/29/2020        NaN     Italy     203591   27682      71252
# 153  4/29/2020        NaN     Spain     236899   24275     132929
# 265  4/29/2020   New York        US     299691   23477          0
#
# [304 rows x 6 columns]

# %%
data.sort_values(by = ['Confirmed'], ascending = True).head(30)
# Out:
#           Date                        State                            Region  \
# 156  4/29/2020                          NaN                          Suriname
# 70   4/29/2020                           MI                          Holy See
# 59   4/29/2020                           CA                            Gambia
# 318  4/29/2020                        Yukon                            Canada
# 217  4/29/2020                    Greenland                           Denmark
# 256  4/29/2020                   Montserrat                                UK
# 144  4/29/2020                          NaN                        Seychelles
# 27   4/29/2020                           UT                           Burundi
# 306  4/29/2020     Turks and Caicos Islands                                UK
# 118  4/29/2020                          NaN                         Nicaragua
# 215  4/29/2020               Grand Princess                            Canada
# ...

# %%
data.sort_values(by = ['Recovered'], ascending = False)
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020       NaN           Spain     236899   24275     132929
# 61   4/29/2020        MA         Germany     161539    6467     120400
# 76   4/29/2020        PA            Iran      93657    5957      73791
# 80   4/29/2020       NaN           Italy     203591   27682      71252
# 229  4/29/2020     Hubei  Mainland China      68128    4512      63616
# ..         ...       ...             ...        ...     ...        ...
# 258  4/29/2020    Nevada              US       4934     230          0
# 257  4/29/2020  Nebraska              US       3851      56          0
# 255  4/29/2020   Montana              US        451      16          0
# 254  4/29/2020  Missouri              US       7660     338          0
# 274  4/29/2020      Ohio              US      17303     937          0
#
# [304 rows x 6 columns]

# %%
data.sort_values(by = ['Recovered'], ascending = False).head(30)
# Out:
#           Date  State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020    NaN           Spain     236899   24275     132929
# 61   4/29/2020     MA         Germany     161539    6467     120400
# 76   4/29/2020     PA            Iran      93657    5957      73791
# 80   4/29/2020    NaN           Italy     203591   27682      71252
# 229  4/29/2020  Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020     NJ          France     165093   24087      48228
# 167  4/29/2020    NaN          Turkey     117589    3081      44040
# 22   4/29/2020     AZ          Brazil      79685    5513      34132
# 158  4/29/2020    NaN     Switzerland      29407    1716      22600
# 78   4/29/2020    NaN         Ireland      20253    1190      13386
# 8    4/29/2020     PA         Austria      15402     580      12779
# 107  4/29/2020    NaN          Mexico      17799    1732      11423
# 15   4/29/2020     OH         Belgium      47859    7501      11283
# ...
